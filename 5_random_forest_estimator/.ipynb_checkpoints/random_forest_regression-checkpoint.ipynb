# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import pickle as pkl
import seaborn as sns
sns.set_theme('talk', palette=sns.color_palette('Set2'))
import time
pd.options.display.max_columns = 30
pd.options.display.max_colwidth = 150

# %% [markdown]
# ## train data load

# %%
infile = open('..//4_data_preparation_for_training//X_train','rb')
X_train = pkl.load(infile)
infile.close()

infile = open('..//4_data_preparation_for_training//X_test','rb')
X_test = pkl.load(infile)
infile.close()

infile = open('..//4_data_preparation_for_training//y_train','rb')
y_train = pkl.load(infile)
infile.close()

infile = open('..//4_data_preparation_for_training//y_test','rb')
y_test = pkl.load(infile)
infile.close()

X_train = X_train.values
X_test = X_test.values
y_train = y_train.values
y_test = y_test.values

# %% [markdown]
# ## random forest regressor and grid search

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
parameters = [{'n_estimators':[30,40,50]}]

# %%
grid_search = GridSearchCV(estimator = RandomForestRegressor(),
                           param_grid = parameters,
                           cv = 3,
#                            n_jobs = -1,
                          )

# %%
start = time.time()

grid_search = grid_search.fit(X_train, y_train)

stop = time.time()
print(round((stop-start)/60,1),'min.')
# Out:
# 12.9 min.

# %%
grid_search.best_score_
# Out:
# 0.7880346411435916

# %%
grid_search.best_params_
# Out:
# {'n_estimators': 50}

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      41.874848      1.820574         0.155725        0.000902
# 1      67.565391      3.936509         0.268237        0.023857
# 2      88.430445      5.415528         0.322413        0.046815
#
#   param_n_estimators                params  split0_test_score  \
# 0                 30  {'n_estimators': 30}           0.776786
# 1                 40  {'n_estimators': 40}           0.771166
# 2                 50  {'n_estimators': 50}           0.779196
#
#    split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 0           0.795011           0.789727         0.787175        0.007656
# 1           0.790411           0.789840         0.783806        0.008941
# 2           0.792421           0.792487         0.788035        0.006250
#
#    rank_test_score
# 0                2
# 1                3
# 2                1

# %%
start = time.time()

model = RandomForestRegressor(n_estimators = 30, random_state = 0)
model.fit(X_train, y_train)

stop = time.time()
print(round((stop-start)/60,1),'min.')
# Out:
# 1.8 min.

# %% [markdown]
# ## model evaluation

# %%
from sklearn.metrics import r2_score

# %%
predictions = model.predict(X_test)

# %%
r2_score(y_test,predictions)
# Out:
# 0.8050209173280132

# %%
plt.figure(figsize=(7,7))
# plt.xlim(0,500)
# plt.ylim(0,500)

# Our predictions
plt.scatter(x=y_test, y=predictions, edgecolor=None, alpha=0.2)
plt.xlabel('test set')
plt.ylabel('predictions')
plt.title('Price')

# Perfect predictions
plt.plot(y_test, y_test ,'r')

# %%
errors = y_test - predictions

# %%
# plt.xlim(-200000,200000)

sns.histplot(errors, bins=20)
plt.title('Error distribution')
# Out:
# Text(0.5, 1.0, 'Error distribution')

# %%
plt.figure(figsize=(10,2))
sns.boxplot(x=errors, showfliers=False)
plt.title('Errors boxplot')
# Out:
# Text(0.5, 1.0, 'Errors boxplot')

# %%
predictions
# Out:
# array([261100.        , 287866.66666667, 586684.46666667, ...,
#        393599.6       , 506213.33333333, 654939.53333333])

# %%
predictions[:20]/y_test[:20]
# Out:
# array([0.96704062, 0.99607843, 0.9456506 , 1.14458333, 1.10947595,
#        0.74325409, 0.94923068, 0.46992346, 1.03647492, 0.994757  ,
#        1.0352381 , 1.43921433, 0.87380681, 0.85704561, 1.02688269,
#        0.94604444, 1.44653346, 0.99060052, 1.01601154, 0.95228395])

# %% [markdown]
# ## k-Fold Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
start = time.time()

accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 5)

stop = time.time()
print(round((stop-start)/60,1),'min.')
# Out:
# 5.5 min.

# %%
accuracies.mean()
# Out:
# 0.7962250990301557

# %%
accuracies.std()
# Out:
# 0.007061378149920908

# %%
accuracies
# Out:
# array([0.7824081 , 0.79721711, 0.80181212, 0.7999243 , 0.79976387])

# %% [markdown]
# ## saving data

# %%
import joblib
joblib.dump(model, 'random_forest_model')
# Out:
# ['random_forest_model']
